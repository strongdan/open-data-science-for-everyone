# %% [markdown]
# Lesson 1 - Open Data Science for everyone
# =========================================

# %% [markdown]
# 1.1 Use Anaconda Repository for data science artifacts
# ------------------------------------------------------

# %% [markdown]
# Open Data Science is about powerful, easy access to the best numerical computing, data processing, and visualization tools today.
#
# With [Anaconda](http://continuum.io/downloads) installed you can use Navigator to start a Jupyter Notebook session and get started right away, which is exactly what we're going to do.

# %% [markdown]
# <center>
# <img src=http://ijstokes-public.s3.amazonaws.com/dspyr/img/AnacondaCIO_Logo width=400 />
# </center>

# %% [markdown]
# This first lesson is to quickly demonstrate how easy it is to perform key aspects of the data science workflow:
#
# * data injest
# * data manipulation
# * data visualization
# * data analysis
# * data modeling
#
# You aren't expected to follow exactly every step.  We'll go into details later.  But this should help motivate you to stick with this course to get the most out of the exciting world of Open Data Science using the Anaconda platform.

# %% [markdown]
# Navigate to [Anaconda Cloud at http://anaconda.org](http://anaconda.org), which provides a public instance of Anaconda Repository, and go to the course account `datasciencepythonr`.  From there you can get a template version of the Notebook for each lesson that will allow you to follow along:
# <p>
# <font size=+1>
# <a href=https://anaconda.org/datasciencepythonr/1-open-data-science-for-everyone>https://anaconda.org/datasciencepythonr/1-open-data-science-for-everyone</a>
# </font>
# </p>

# %% [markdown]
# 1.2 Use Anaconda Navigator to open and run Jupyter Notebooks
# ------------------------------------------------------------
#
# Start Anaconda Navigator and click the *"Launch"* button to start Jupyter Notebook:
#
# ![Anaconda Navigator](http://ijstokes-public.s3.amazonaws.com/dspyr/img/screenshot_anaconda_navigator.png)

# %% [markdown]
# ### Open Data Science = Your Toolbox, Your Tools
#
# Anaconda hands you a pretty well stocked tool box for Open Data Science, but more importantly it gives you agility to work quickly and easily on many different problems, and flexibility to customize the tools you have on hand through the Conda package management system.
#
# Windows, Mac, and Linux: everyone can work from the same starting point.  No administrator rights required, no interfering with software and tools you already have installed.

# %% [markdown]
# 1.3 Perform fundamental Jupyter operations
# ------------------------------------------
#
# More tips under the *Help* menu entry *Keyboard shortcuts*
#
# * Cells
# * Execute
#     * `SHIFT-ENTER` to execute a cell and go to the next cell
#     * `CTRL-ENTER` to execute a cell but keep focus on the same cell
#     * `ALT-ENTER` to execute a cell and insert a new cell after it
# * Stop
# * Insert new cell
# * Re-order cells
# * Clear output
# * Restart kernel

# %% [markdown]
# 1.4 Injest, analyze, and clean data with Pandas
# -----------------------------------------------
# <center>
# <img src=http://pandas.pydata.org/_static/pandas_logo.png />
# </center>
# Reference: [Pandas documentation](http://pandas.pydata.org)

# %% [markdown]
# ### Get Your Hands Dirty, and Code First
#
# Once upon a time the coding part was complicated, time consuming, and only possible by experts who were often far removed from the line-of-business objectives they are trying to serve.  Today you need to move beyond spreadsheets for data insights and need to be empowered to find answers yourself, with little or no reference to a distant analytics team.
#
# Anaconda was created to empower anyone who can use Excel to have in their hands the tools they need to injest data, analyze it, visualize it, build interactive apps, and deploy production analysis models at scale.
#
# So I will start by demonstrating a simple analysis workflow of a well known sample data set of 400 cars from the 1970s.

# %%
import pandas as pd

pd.set_option("display.max_rows",10)

# %% [markdown]
# Normally we wouldn't read data this way, but this is some sample data that is bundled with Bokeh for convenience

# %%
from bokeh.sampledata.autompg import autompg

# %% [markdown]
# In Python just typing the name of a variable will show you a "representation" of that variable. In the case of a `pandas.DataFrame` we'll see a data table.

# %%
autompg
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 0    18.0    8  307.0  130    3504   12.0  70       1
# 1    15.0    8  350.0  165    3693   11.5  70       1
# 2    18.0    8  318.0  150    3436   11.0  70       1
# 3    16.0    8  304.0  150    3433   12.0  70       1
# 4    17.0    8  302.0  140    3449   10.5  70       1
# ..    ...  ...    ...  ...     ...    ...  ..     ...
# 387  27.0    4  140.0   86    2790   15.6  82       1
# 388  44.0    4   97.0   52    2130   24.6  82       2
# 389  32.0    4  135.0   84    2295   11.6  82       1
# 390  28.0    4  120.0   79    2625   18.6  82       1
# 391  31.0    4  119.0   82    2720   19.4  82       1
#
#                           name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ..                         ...
# 387            ford mustang gl
# 388                  vw pickup
# 389              dodge rampage
# 390                ford ranger
# 391                 chevy s-10
#
# [392 rows x 9 columns]

# %% [markdown]
# Look at the data, sorted by fuel efficiency dimension `mpg`

# %%
autompg.sort_values(by='mpg')
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin                  name
# 28    9.0    8  304.0  193    4732   18.5  70       1              hi 1200d
# 26   10.0    8  307.0  200    4376   15.0  70       1             chevy c20
# 25   10.0    8  360.0  215    4615   14.0  70       1             ford f250
# 27   11.0    8  318.0  210    4382   13.5  70       1            dodge d200
# 123  11.0    8  350.0  180    3664   11.0  73       1      oldsmobile omega
# ..    ...  ...    ...  ...     ...    ...  ..     ...                   ...
# 324  43.4    4   90.0   48    2335   23.7  80       2    vw dasher (diesel)
# 388  44.0    4   97.0   52    2130   24.6  82       2             vw pickup
# 323  44.3    4   90.0   48    2085   21.7  80       2  vw rabbit c (diesel)
# 327  44.6    4   91.0   67    1850   13.8  80       3   honda civic 1500 gl
# 320  46.6    4   86.0   65    2110   17.9  80       3             mazda glc
#
# [392 rows x 9 columns]

# %% [markdown]
# Notice the first word in each name entry is the *make*.  We'll use this to add a `make` field to the `pandas.DataFrame` object:

# %%
autompg['make'] = pd.Series((n.split()[0] for n in autompg.name), index=autompg.index)

# %% [markdown]
# Let's look at a sorted list of this new dimension

# %%
sorted(autompg.make.unique())
# Out:
# ['amc',
#  'audi',
#  'bmw',
#  'buick',
#  'cadillac',
#  'capri',
#  'chevroelt',
#  'chevrolet',
#  'chevy',
#  'chrysler',
#  'datsun',
#  'dodge',
#  'fiat',
#  'ford',
#  'hi',
#  'honda',
#  'maxda',
#  'mazda',
#  'mercedes',
#  'mercedes-benz',
#  'mercury',
#  'nissan',
#  'oldsmobile',
#  'opel',
#  'peugeot',
#  'plymouth',
#  'pontiac',
#  'renault',
#  'saab',
#  'subaru',
#  'toyota',
#  'toyouta',
#  'triumph',
#  'vokswagen',
#  'volkswagen',
#  'volvo',
#  'vw']

# %% [markdown]
# Several makes have spelling errors or inconsistencies. Pandas can help us fix those in place:

# %%
autompg.loc[autompg.make == 'chevroelt', 'make'] = 'chevrolet'
autompg.loc[autompg.make == 'chevy',     'make'] = 'chevrolet'
autompg.loc[autompg.make == 'maxda',     'make'] = 'mazda'
autompg.loc[autompg.make == 'mercedes',  'make'] = 'mercedes-benz'
autompg.loc[autompg.make == 'toyouta',   'make'] = 'toyota'
autompg.loc[autompg.make == 'vokswagen', 'make'] = 'volkswagen'
autompg.loc[autompg.make == 'vw',        'make'] = 'volkswagen'

# %%
with pd.option_context('display.max_rows', 999):
    print(autompg.groupby('make').size())
# Out:
# [1, 1, 1, 1, 2, 2, 3, 3, 4, 4, 4, 6, 6, 7, 8, 8, 10, 11, 12, 13, 16, 17, 22, 23, 26, 27, 28, 31, 47, 48]

# %% [markdown]
# 1.5 Visualize data with Bokeh
# -----------------------------
# <center>
# <img src=https://bokeh.github.io/images/logo.svg />
# </center>
# Reference: [Bokeh documentation](http://bokeh.pydata.org)

# %%
from bokeh.charts import Scatter, Histogram
from bokeh.models import HoverTool
from bokeh.io import output_notebook, show

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5c002004-de52-4143-a858-df1b11a23b94">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# What trend do we observe in this data set?
# What was happening through the 1970s that might cause this?

# %%
s = Scatter(data=autompg, x='yr', y='mpg', height=400)
show(s)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e80bcfe9-d75c-4949-9b8d-b987fe2d86ba"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("e80bcfe9-d75c-4949-9b8d-b987fe2d86ba").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e80bcfe9-d75c-4949-9b8d-b987fe2d86ba");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e80bcfe9-d75c-4949-9b8d-b987fe2d86ba' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1d829870-063a-40d1-be66-30971ec4b289":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"c9352f7a-26b0-4106-812a-a019eec3fdcc","type":"Circle"},{"attributes":{},"id":"5276ebed-b8b8-408e-bbf0-ee4bae0b5f0e","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"774127ee-9909-4096-96a2-05a0e491dba3","type":"ColumnDataSource"},"glyph":{"id":"c9352f7a-26b0-4106-812a-a019eec3fdcc","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"f08298d8-43c1-46f5-8533-16d797ec99a4","type":"GlyphRenderer"},{"attributes":{},"id":"3e020fbf-0cfe-46c4-822a-2b47c505ef32","type":"BasicTicker"},{"attributes":{},"id":"4c1d0d8b-6534-4b78-b8c0-f52a8b03e42b","type":"ToolEvents"},{"attributes":{"location":"top_left","plot":{"id":"307d3380-ed8d-4497-97b0-15bc302c1ff4","subtype":"Chart","type":"Plot"}},"id":"13264c4a-2c2a-465b-8b46-7eeb538fd688","type":"Legend"},{"attributes":{"below":[{"id":"4b4a823a-5278-4a52-9f01-a3393d6ed124","type":"LinearAxis"}],"css_classes":null,"height":400,"left":[{"id":"f6d4a768-a585-4848-bccc-3655c83640e5","type":"LinearAxis"}],"renderers":[{"id":"2a9a69a3-d206-48c1-a8ca-b3c0f3e8f013","type":"BoxAnnotation"},{"id":"f08298d8-43c1-46f5-8533-16d797ec99a4","type":"GlyphRenderer"},{"id":"13264c4a-2c2a-465b-8b46-7eeb538fd688","type":"Legend"},{"id":"4b4a823a-5278-4a52-9f01-a3393d6ed124","type":"LinearAxis"},{"id":"f6d4a768-a585-4848-bccc-3655c83640e5","type":"LinearAxis"},{"id":"522bf33f-bea1-4a34-9090-d72c40822a53","type":"Grid"},{"id":"66eb0122-f0bf-4495-b3d3-7240dac840c1","type":"Grid"}],"title":{"id":"f76df11b-13fc-4ee9-8723-276c2e990857","type":"Title"},"tool_events":{"id":"4c1d0d8b-6534-4b78-b8c0-f52a8b03e42b","type":"ToolEvents"},"toolbar":{"id":"ad9ab7dd-a6b5-46a2-8286-256da294b880","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"4e324d7c-6264-4bd1-842b-d76f3565d4ea","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"d955393f-68b5-4d87-87dc-4471593bfc1d","type":"Range1d"}},"id":"307d3380-ed8d-4497-97b0-15bc302c1ff4","subtype":"Chart","type":"Plot"},{"attributes":{"dimension":1,"plot":{"id":"307d3380-ed8d-4497-97b0-15bc302c1ff4","subtype":"Chart","type":"Plot"},"ticker":{"id":"3e020fbf-0cfe-46c4-822a-2b47c505ef32","type":"BasicTicker"}},"id":"66eb0122-f0bf-4495-b3d3-7240dac840c1","type":"Grid"},{"attributes":{"plot":null,"text":null},"id":"f76df11b-13fc-4ee9-8723-276c2e990857","type":"Title"},{"attributes":{},"id":"f5a4af1f-27d4-4578-bfb3-6897c88eeb9a","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"303dd288-dd70-4522-81a5-06164513542b","type":"PanTool"},{"id":"52e0dc0b-eb79-4766-b3d4-713c94b58d29","type":"WheelZoomTool"},{"id":"c189baa6-db71-43a0-8ff4-0fb24227dd99","type":"BoxZoomTool"},{"id":"961d6096-53ac-4a50-96b2-e182abe42484","type":"SaveTool"},{"id":"5e6d2564-ca0d-4443-bf79-7202a966cfcc","type":"ResetTool"},{"id":"7189d045-a873-4d8d-a6fc-356a2b6c35af","type":"HelpTool"}]},"id":"ad9ab7dd-a6b5-46a2-8286-256da294b880","type":"Toolbar"},{"attributes":{"callback":null,"end":50.36,"start":5.24},"id":"d955393f-68b5-4d87-87dc-4471593bfc1d","type":"Range1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2a9a69a3-d206-48c1-a8ca-b3c0f3e8f013","type":"BoxAnnotation"},{"attributes":{"axis_label":"mpg","formatter":{"id":"5276ebed-b8b8-408e-bbf0-ee4bae0b5f0e","type":"BasicTickFormatter"},"plot":{"id":"307d3380-ed8d-4497-97b0-15bc302c1ff4","subtype":"Chart","type":"Plot"},"ticker":{"id":"3e020fbf-0cfe-46c4-822a-2b47c505ef32", ...

# %% [markdown]
# Let's just look at one make from each of the US, Germany, and Japan

# %%
s = Scatter(data=autompg[autompg.make.isin('ford volkswagen honda'.split())],
            x='yr', y='mpg', color='make', height=400)
show(s)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cfa3376c-bf2f-4d6c-84d1-c40c259b9258"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("cfa3376c-bf2f-4d6c-84d1-c40c259b9258").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cfa3376c-bf2f-4d6c-84d1-c40c259b9258");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cfa3376c-bf2f-4d6c-84d1-c40c259b9258' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bd759619-7d5a-429d-aadf-b5b7cd3945ab":{"roots":{"references":[{"attributes":{},"id":"bcb11f25-b881-4b47-9570-445404437f23","type":"BasicTicker"},{"attributes":{"data_source":{"id":"697cf5cf-fa67-4eac-9e8c-e73b3817f704","type":"ColumnDataSource"},"glyph":{"id":"906944ee-639a-4221-8efd-7d6133e66f45","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"286a0f4f-f7bf-4fef-b426-6bf420935054","type":"GlyphRenderer"},{"attributes":{},"id":"92913373-4beb-408c-974a-97bbda13e610","type":"ToolEvents"},{"attributes":{"axis_label":"mpg","formatter":{"id":"a693a412-ace4-4ca4-9e1f-7adc55f374d1","type":"BasicTickFormatter"},"plot":{"id":"3692a5ec-1fb7-4165-a83d-5b706ff3e4ce","subtype":"Chart","type":"Plot"},"ticker":{"id":"9ed4c359-02bd-4b5b-869e-ffd40745025c","type":"BasicTicker"}},"id":"4d6e9441-77f1-4994-9996-0b6ca09d15ac","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#5ab738"},"line_color":{"value":"#5ab738"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"9b5536da-f0bd-4f3e-a6d9-d2058bc0f082","type":"Circle"},{"attributes":{"data_source":{"id":"182abbb8-81ab-4c14-8b48-afcabd58c239","type":"ColumnDataSource"},"glyph":{"id":"9b5536da-f0bd-4f3e-a6d9-d2058bc0f082","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"da52d8fa-baca-4fb2-9b9c-441aa76bba71","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"3692a5ec-1fb7-4165-a83d-5b706ff3e4ce","subtype":"Chart","type":"Plot"},"ticker":{"id":"9ed4c359-02bd-4b5b-869e-ffd40745025c","type":"BasicTicker"}},"id":"683da98a-5c8d-43e3-87b6-024beedc9ff1","type":"Grid"},{"attributes":{"data_source":{"id":"0634a02f-ae1f-4301-879a-24fba1b3ac2c","type":"ColumnDataSource"},"glyph":{"id":"5150028b-c587-421c-9ace-99e327e1725a","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"2864528c-ac2d-4e08-ab76-f1077c86adda","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"},{"make":"honda"}],"make":["honda","honda","honda","honda","honda","honda","honda","honda","honda","honda","honda","honda","honda"],"x_values":[74,75,76,77,78,78,80,80,81,81,82,82,82],"y_values":{"__ndarray__":"AAAAAAAAOEAAAAAAAIBAQAAAAAAAgEBAAAAAAACAP0DNzMzMzAxCQAAAAAAAgD1AzczMzMxMRkAzMzMzMzNAQM3MzMzMjEFAmpmZmZnZQEAAAAAAAABCQAAAAAAAAENAAAAAAAAAQEA=","dtype":"float64","shape":[13]}}},"id":"182abbb8-81ab-4c14-8b48-afcabd58c239","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"177b21f4-0a39-4dc6-b7c4-30bc931a0697","type":"PanTool"},{"id":"ec5968a4-2296-41b1-b509-a93358d2aec4","type":"WheelZoomTool"},{"id":"32ce44d6-28fd-456f-8538-f0332f07b9fe","type":"BoxZoomTool"},{"id":"dd2ab26d-4c4d-460a-b5a8-fd7cd19edfed","type":"SaveTool"},{"id":"76224650-90e2-43dd-9819-00c7c316872f","type":"ResetTool"},{"id":"9206d9b1-8b20-4278-af21-66a43541809d","type":"HelpTool"}]},"id":"5e9ea2f9-4069-4c23-9a2e-89c4b5e8a9a0","type":"Toolbar"},{"attributes":{"plot":{"id":"3692a5ec-1fb7-4165-a83d-5b706ff3e4ce","subtype":"Chart","type":"Plot"},"ticker":{"id":"bcb11f25-b881-4b47-9570-445404437f23","type":"BasicTicker"}},"id":"f5a876a9-cddf-44fa-ac70-81d48e493ab1","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"91ec167f-2010-4f5d-b328-ad839f377f6f","type":"BoxAnnotation"},{"attributes":{},"id":"831ceaf5-8819-42b7-950 ...

# %% [markdown]
# How did we do that? With a sub-select on the `autompg` object using something called *"fancy indexing"* to select just the rows that have a make that is one of `ford volkswagen honda`.

# %%
autompg[autompg.make.isin('ford volkswagen honda'.split())]
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 4    17.0    8  302.0  140    3449   10.5  70       1
# 5    15.0    8  429.0  198    4341   10.0  70       1
# 17   21.0    6  200.0   85    2587   16.0  70       1
# 19   26.0    4   97.0   46    1835   20.5  70       2
# 25   10.0    8  360.0  215    4615   14.0  70       1
# ..    ...  ...    ...  ...     ...    ...  ..     ...
# 378  32.0    4   91.0   67    1965   15.7  82       3
# 383  22.0    6  232.0  112    2835   14.7  82       1
# 387  27.0    4  140.0   86    2790   15.6  82       1
# 388  44.0    4   97.0   52    2130   24.6  82       2
# 390  28.0    4  120.0   79    2625   18.6  82       1
#
#                              name        make
# 4                     ford torino        ford
# 5                ford galaxie 500        ford
# 17                  ford maverick        ford
# 19   volkswagen 1131 deluxe sedan  volkswagen
# 25                      ford f250        ford
# ..                            ...         ...
# 378            honda civic (auto)       honda
# 383                ford granada l        ford
# 387               ford mustang gl        ford
# 388                     vw pickup  volkswagen
# 390                   ford ranger        ford
#
# [83 rows x 10 columns]

# %% [markdown]
# Use Bokeh to add some simple interactivity

# %%
s = Scatter(data=autompg[autompg.make.isin('ford volkswagen honda'.split())],
            x='yr', y='mpg', color='make',
            height=400, width=800,
            title='Fuel efficiency of selected vehicles from 1970-1982',
            tools='hover, box_zoom, lasso_select, save, reset',
            tooltips=[
                ('Make','@make'),
                ('MPG','@mpg'),
                ('hp','@hp')]
           )

show(s)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a3d7867e-049a-48ef-88fb-78218b7186cd"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("a3d7867e-049a-48ef-88fb-78218b7186cd").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a3d7867e-049a-48ef-88fb-78218b7186cd");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a3d7867e-049a-48ef-88fb-78218b7186cd' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"53326c13-08b1-403d-b133-af714410f774":{"roots":{"references":[{"attributes":{},"id":"0c3721b5-d0e7-4a8e-b740-f376b6894514","type":"BasicTickFormatter"},{"attributes":{},"id":"a778bb3b-5c86-493f-9ed3-446ad8f31b5a","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x_values","y_values","mpg","hp"],"data":{"chart_index":[{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"},{"make":"volkswagen"}],"hp":[46,60,54,76,46,67,71,70,70,71,78,78,48,71,71,76,48,48,62,74,74,52],"make":["volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen","volkswagen"],"mpg":{"__ndarray__":"AAAAAAAAOkAAAAAAAAA7QAAAAAAAADdAAAAAAAAANkAAAAAAAAA6QAAAAAAAADpAAAAAAAAAOUAAAAAAAAA9QAAAAAAAAD1AAAAAAACAPUAAAAAAAAA9QAAAAAAAgD5AzczMzMyMRUAAAAAAAIA/QGZmZmZm5j9AAAAAAADAREBmZmZmZiZGQDMzMzMzs0VAzczMzMzMPUAAAAAAAIBAQAAAAAAAAEJAAAAAAAAARkA=","dtype":"float64","shape":[22]},"x_values":[70,71,72,72,73,74,75,75,76,76,77,77,78,78,79,80,80,80,80,81,82,82],"y_values":{"__ndarray__":"AAAAAAAAOkAAAAAAAAA7QAAAAAAAADdAAAAAAAAANkAAAAAAAAA6QAAAAAAAADpAAAAAAAAAOUAAAAAAAAA9QAAAAAAAAD1AAAAAAACAPUAAAAAAAAA9QAAAAAAAgD5AzczMzMyMRUAAAAAAAIA/QGZmZmZm5j9AAAAAAADAREBmZmZmZiZGQDMzMzMzs0VAzczMzMzMPUAAAAAAAIBAQAAAAAAAAEJAAAAAAAAARkA=","dtype":"float64","shape":[22]}}},"id":"65d8ceed-79e8-4a47-ae54-c82fdd2e373e","type":"ColumnDataSource"},{"attributes":{},"id":"a90928e6-f424-4a1a-9d82-ab8ed3b6101f","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"31910720-b529-4013-833c-1c220263fa56","type":"HoverTool"},{"id":"fbde2e7f-9752-4204-b1ce-bd178c806591","type":"BoxZoomTool"},{"id":"4cb86a3b-6419-4c6b-a290-89a334360a50","type":"LassoSelectTool"},{"id":"4d909545-1176-4c74-aba6-7e1914ab3fcd","type":"SaveTool"},{"id":"1ccf7ac0-c6f1-40a1-bbb4-ed1bce8a0afb","type":"ResetTool"},{"id":"dd30796d-04d1-4460-8d45-6602b9fc8078","type":"HoverTool"}]},"id":"99583640-c36c-4dd2-ad94-f14b9ab9c6c8","type":"Toolbar"},{"attributes":{"plot":{"id":"83b22549-b073-49c9-b9e0-b9c6df390ff8","subtype":"Chart","type":"Plot"},"ticker":{"id":"a778bb3b-5c86-493f-9ed3-446ad8f31b5a","type":"BasicTicker"}},"id":"a9611fbe-0fa2-4c1f-9326-a43801b2b64b","type":"Grid"},{"attributes":{"label":{"value":"honda"},"renderers":[{"id":"36d005b0-cdd0-4622-b057-672acd74e9ba","type":"GlyphRenderer"}]},"id":"1090e46a-5ed6-4821-afab-56136bc93aa5","type":"LegendItem"},{"attributes":{"axis_label":"yr","formatter":{"id":"0c3721b5-d0e7-4a8e-b740-f376b6894514","type":"BasicTickFormatter"},"plot":{"id":"83b22549-b073-49c9-b9e0-b9c6df390ff8","subtype":"Chart","type":"Plot"},"ticker":{"id":"a778bb3b-5c86-493f-9ed3-446ad8f31b5a","type":"BasicTicker"}},"id":"ad6a76ba-f7a7-4f21-83b0-9c54a67b3415","type":"LinearAxis"},{"attributes":{"label":{"value":"ford"},"renderers":[{"id":"b0a1233e-21c3-48f9-a095-b699acae88e2","type":"GlyphRenderer"}]},"id":"43cc0584-cb3f-43b9-9f28-76e032de2719","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"da77598d-b6c2-415b-81d7-d19813e94e4b","type":"Circle"},{"attributes":{"callback":null,"plot":{"id":"83b22549-b073-49c9-b9e0-b9c6df390ff8","subtype":"Chart","type":"Plot"}},"id":"31910720-b529-4013-833c-1c220263fa56","type":"HoverTool"}, ...

# %% [markdown]
# 1.6 Create machine learning and predictive models with Scikit-Learn
# --------------------------------------------------------------------
# <center>
# <img src=http://scikit-learn.org/stable/_images/scikit-learn-logo-notext.png />
# </center>
# Reference: [Scikit-Learn documentation](http://scikit-learn.org/)

# %%
from sklearn.svm          import SVC                    as support_vector_classifier
from sklearn.ensemble     import RandomForestClassifier as random_forest_classifier
from sklearn.neighbors    import KNeighborsClassifier   as knn_classifier
from sklearn.linear_model import LinearRegression       as linear_regression_classifier

from sklearn.cross_validation import train_test_split
# Out:
# C:\Users\brocd8s\AppData\Local\Continuum\Anaconda3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
train, test = train_test_split(autompg, train_size=0.80, random_state=123)
train = train.copy()
test  = test.copy()

# %% [markdown]
# ### Linear Regression Model

# %%
model = linear_regression_classifier()
model.fit(train['cyl displ hp weight accel yr'.split()],
          train['mpg'].values.ravel())
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.score(test['cyl displ hp weight accel yr'.split()],
#            test['mpg'].astype(int).values.ravel()) # for discrete predictions
            test['mpg'].values.ravel())              # for continuous predictions
# Out:
# 0.75077542748160853

# %%
predictions = model.predict(test['cyl displ hp weight accel yr'.split()])
predictions
# Out:
# array([ 16.93513471,  31.44386166,  13.92513989,  25.33100232,
#         30.86517173,  16.12912297,  29.84316806,  20.79424901,
#         17.51682663,  33.5962678 ,  15.16484689,  24.05681003,
#         13.43861853,  30.4849891 ,  15.96175622,  22.14058281,
#         29.18249959,   7.26444002,  12.34592112,  14.11414099,
#         22.31888799,  28.78553786,  29.70553983,  35.29035859,
#         34.53708373,  16.04079521,  26.86016519,  31.90293837,
#         22.70010858,  27.39754987,  23.10237142,  31.48471994,
#         17.0945224 ,  20.83682113,  27.73349153,  28.37221631,
#         27.18683665,  27.98877592,  26.11857502,  11.08719175,
#         17.4036681 ,  23.45466615,  25.0567287 ,  21.985068  ,
#         20.55618207,  20.54065738,  28.84321132,  29.74538267,
#         24.29508899,  20.39074464,  20.98390062,  33.4709278 ,
#         16.27399269,  22.37692882,  22.76363708,  14.67741727,
#          7.73764472,  24.38242977,  19.44958426,  30.11714922,
#         16.5131058 ,   6.38634806,  24.59175118,  27.26877553,
#         20.30193067,  33.77916119,  30.9261231 ,  24.59543879,
#         26.23317754,  22.89863311,  25.04347344,  27.96854099,
#         25.57556152,  11.91524446,  26.96353645,  30.35319343,
#         28.79986239,  13.57871975,  21.44849095])

# %%
test['mpg']
# Out:
# 220    17.0
# 245    39.4
# 134    16.0
# 147    24.0
# 390    28.0
#        ...
# 274    21.6
# 318    37.0
# 380    25.0
# 114    15.0
# 189    22.0
# Name: mpg, dtype: float64

# %%
h = Histogram(predictions - test.mpg, height=400)
show(h)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4c172bc8-1c5a-48b6-8e65-ce0c67b0952d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("4c172bc8-1c5a-48b6-8e65-ce0c67b0952d").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4c172bc8-1c5a-48b6-8e65-ce0c67b0952d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4c172bc8-1c5a-48b6-8e65-ce0c67b0952d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a2651f0a-acfe-43c2-94ab-a57afd0d382f":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"649db8ca-742a-4938-b931-93a1d9f292e5","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"7b003012-ac89-4546-ba04-4cb0601acdb0","subtype":"Chart","type":"Plot"}},"id":"004ca71e-3a80-4710-9840-77831b72ce68","type":"ResetTool"},{"attributes":{"plot":{"id":"7b003012-ac89-4546-ba04-4cb0601acdb0","subtype":"Chart","type":"Plot"}},"id":"f434da0e-291c-4052-81b4-eb75b81943dc","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(4.799242, 7.056810]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[9.0],"label":["(4.799242, 7.056810]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.257567779627559],"x":["5.928025999999999"],"y":[4.5]}},"id":"0e3d769c-8781-40b0-8282-d3fc78468d8e","type":"ColumnDataSource"},{"attributes":{"axis_label":"mpg","formatter":{"id":"598b60cf-8e32-4bbf-a91d-7a431dea1770","type":"BasicTickFormatter"},"plot":{"id":"7b003012-ac89-4546-ba04-4cb0601acdb0","subtype":"Chart","type":"Plot"},"ticker":{"id":"2401d189-6523-43b9-a403-2a7be1c5f821","type":"BasicTicker"}},"id":"3c9d772c-ea18-4c9f-a38b-bb40664076ee","type":"LinearAxis"},{"attributes":{"data_source":{"id":"0e3d769c-8781-40b0-8282-d3fc78468d8e","type":"ColumnDataSource"},"glyph":{"id":"8939abab-53b9-42dc-bad7-e689d753cf82","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"8fb0731e-9a7c-42ab-979e-82d788911c20","type":"GlyphRenderer"},{"attributes":{"axis_label":"Count( Mpg )","formatter":{"id":"e1f6ec25-9052-41c6-aa27-a8a82430b8dd","type":"BasicTickFormatter"},"plot":{"id":"7b003012-ac89-4546-ba04-4cb0601acdb0","subtype":"Chart","type":"Plot"},"ticker":{"id":"f2c9ecf1-6f40-4486-a5e0-3f727d54c476","type":"BasicTicker"}},"id":"cb6c67e0-5f7b-47eb-b385-ac93adf65936","type":"LinearAxis"},{"attributes":{},"id":"598b60cf-8e32-4bbf-a91d-7a431dea1770","type":"BasicTickFormatter"},{"attributes":{},"id":"f2c9ecf1-6f40-4486-a5e0-3f727d54c476","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"7b003012-ac89-4546-ba04-4cb0601acdb0","subtype":"Chart","type":"Plot"},"ticker":{"id":"f2c9ecf1-6f40-4486-a5e0-3f727d54c476","type":"BasicTicker"}},"id":"8211746b-54e1-4fe8-8c93-46f2bfcaf062","type":"Grid"},{"attributes":{},"id":"e1f6ec25-9052-41c6-aa27-a8a82430b8dd","type":"BasicTickFormatter"},{"attributes":{},"id":"2401d189-6523-43b9-a403-2a7be1c5f821","type":"BasicTicker"},{"attributes":{"data_source":{"id":"0599477f-81a1-4a51-9104-cf027747b983","type":"ColumnDataSource"},"glyph":{"id":"b7de548e-8f23-4bb8-bfb7-260a51a8b82c","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"98ee5857-8582-4097-a0bc-ee0dc7e6df48","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["[-11.003732, -8.746164]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[3.0],"label":["[-11.003732, -8.746164]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.257567779627559],"x":["-9.874948"],"y":[1.5]}},"id":"471bc2f8-0143-4088-aa96-25e2832acf87","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(-8.746164, -6.488597]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":["(-8.746164, -6.488597]"],"line_alpha":[1.0],"line_color":["black"],"width":[2.257567779627558],"x":["-7.6173805"],"y":[1.0]}},"id":"1eae7f52-d6c5-47e9-bef2-6abf ...

# %%
delta          = predictions - test.mpg
test['mpg_lr'] = predictions
test['lr']     = delta
test[delta.abs() > 5]
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 245  39.4    4   85.0   70    2070   18.6  78       3
# 327  44.6    4   91.0   67    1850   13.8  80       3
# 273  17.0    6  163.0  125    3140   13.6  78       2
# 240  21.5    4  121.0  110    2600   12.8  77       2
# 307  41.5    4   98.0   76    2144   14.7  80       2
# ..    ...  ...    ...  ...     ...    ...  ..     ...
# 42   13.0    8  400.0  170    4746   12.0  71       1
# 41   12.0    8  383.0  180    4955   11.5  71       1
# 272  20.3    5  131.0  103    2830   15.9  78       2
# 274  21.6    4  121.0  115    2795   15.7  78       2
# 318  37.0    4  119.0   92    2434   15.0  80       3
#
#                          name        make     mpg_lr         lr
# 245            datsun b210 gx      datsun  31.443862  -7.956138
# 327       honda civic 1500 gl       honda  33.596268 -11.003732
# 273               volvo 264gl       volvo  24.056810   7.056810
# 240                  bmw 320i         bmw  26.860165   5.360165
# 307                 vw rabbit  volkswagen  31.902938  -9.597062
# ..                        ...         ...        ...        ...
# 42   ford country squire (sw)        ford   7.737645  -5.262355
# 41          dodge monaco (sw)       dodge   6.386348  -5.613652
# 272                 audi 5000        audi  26.233178   5.933178
# 274                saab 99gle        saab  26.963536   5.363536
# 318      datsun 510 hatchback      datsun  30.353193  -6.646807
#
# [16 rows x 12 columns]

# %% [markdown]
# ### Random Forest Classifier

# %%
model = random_forest_classifier(n_estimators=100)
model.fit(train['cyl displ hp weight accel yr'.split()],
          train['mpg'].astype(int).values.ravel())
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=100, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %% [markdown]
# So how does Random Forest compare to Linear Regression?

# %%
model.score(test['cyl displ hp weight accel yr'.split()],
            test['mpg'].astype(int).values.ravel()) # for discrete predictions
#            test['mpg'].values.ravel())              # for continuous predictions
# Out:
# 0.13924050632911392

# %%
predictions = model.predict(test['cyl displ hp weight accel yr'.split()])
predictions
# Out:
# array([15, 31, 14, 23, 31, 18, 23, 18, 15, 31, 16, 20, 15, 30, 15, 20, 26,
#        13, 14, 15, 20, 26, 26, 39, 40, 15, 21, 33, 23, 26, 20, 27, 19, 19,
#        19, 27, 24, 32, 23, 11, 17, 20, 21, 30, 18, 15, 26, 28, 21, 20, 25,
#        38, 16, 17, 20, 16, 13, 21, 23, 31, 15, 13, 24, 24, 17, 39, 34, 20,
#        20, 19, 24, 35, 27, 13, 19, 23, 22, 13, 20])

# %%
delta = predictions - test.mpg
test['mpg_rf'] = predictions
test['rf'] = delta
test[delta.abs() > 5]
# Out:
#       mpg  cyl  displ  hp  weight  accel  yr  origin  \
# 245  39.4    4   85.0  70    2070   18.6  78       3
# 327  44.6    4   91.0  67    1850   13.8  80       3
# 307  41.5    4   98.0  76    2144   14.7  80       2
# 381  38.0    6  262.0  85    3015   17.0  82       1
# 329  29.8    4   89.0  62    1845   15.3  80       2
# 318  37.0    4  119.0  92    2434   15.0  80       3
#
#                                   name        make     mpg_lr         lr  \
# 245                     datsun b210 gx      datsun  31.443862  -7.956138
# 327                honda civic 1500 gl       honda  33.596268 -11.003732
# 307                          vw rabbit  volkswagen  31.902938  -9.597062
# 381  oldsmobile cutlass ciera (diesel)  oldsmobile  27.733492 -10.266508
# 329                   vokswagen rabbit  volkswagen  33.779161   3.979161
# 318               datsun 510 hatchback      datsun  30.353193  -6.646807
#
#      mpg_rf    rf
# 245      31  -8.4
# 327      31 -13.6
# 307      33  -8.5
# 381      19 -19.0
# 329      39   9.2
# 318      23 -14.0

# %%
h = Histogram(delta, height=300)
show(h)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d27f3cc2-c688-4edd-ab5b-82357a20bab2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("d27f3cc2-c688-4edd-ab5b-82357a20bab2").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d27f3cc2-c688-4edd-ab5b-82357a20bab2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd27f3cc2-c688-4edd-ab5b-82357a20bab2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b7bd4ab8-d01f-413b-8ce6-ef759e7ae3ea":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["[-19.000000, -17.825000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":["[-19.000000, -17.825000]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.1750000000000007],"x":["-18.4125"],"y":[0.5]}},"id":"8c015335-86ad-4d38-8a7f-3dce9060751b","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(-17.825000, -16.650000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(-17.825000, -16.650000]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.1750000000000007],"x":["-17.237499999999997"],"y":[0.0]}},"id":"55918e13-16e6-405f-b132-aea7e0e36ae5","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ac5dad0e-d91b-46c3-844f-9b3905c5854b","type":"Rect"},{"attributes":{},"id":"33fa988f-41ea-43f7-8431-5cd413507b84","type":"ToolEvents"},{"attributes":{"data_source":{"id":"8c015335-86ad-4d38-8a7f-3dce9060751b","type":"ColumnDataSource"},"glyph":{"id":"ac5dad0e-d91b-46c3-844f-9b3905c5854b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"1cacf587-7edb-4dcb-bbc5-cf372476ac6b","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(-16.650000, -15.475000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(-16.650000, -15.475000]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.174999999999999],"x":["-16.0625"],"y":[0.0]}},"id":"616771ee-0b18-41f3-a5d1-71e2d2dc6324","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1b51b30f-6346-4cf9-95c7-2262d429b46e","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(-9.600000, -8.425000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":["(-9.600000, -8.425000]"],"line_alpha":[1.0],"line_color":["black"],"width":[1.1750000000000007],"x":["-9.0125"],"y":[0.5]}},"id":"07679fa0-c352-45a5-bbb3-c1c6a15921aa","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"583115dd-43a4-408d-bc83-f1c5093d4eba","type":"ColumnDataSource"},"glyph":{"id":"408e043f-90b7-4156-9f22-ee5172f0351b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"56b66a75-fef0-4d65-a1cc-797ce67330bc","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"fcc38a31-275c-486d-9fbd-12dfa958f75f","type":"LinearAxis"}],"css_classes":null,"height":300,"left":[{"id":"06212d33-6cd6-49fa-b647-bea5dde056e4","type":"LinearAxis"}],"renderers":[{"id":"db77e5df-645a-4c4d-8991-3a137805e362","type":"BoxAnnotation"},{"id":"1cacf587-7edb-4dcb-bbc5-cf372476ac6b","type":"GlyphRenderer"},{"id":"d583f375-3a68-481c-b7c6-de85e20d69c8","type":"GlyphRenderer"},{"id":"35c1b22b-9ab3-4ad9-af41-f642923722bd","type":"GlyphRenderer"},{"id":"ea0ae7da-8616-4bff-b89d-65f296b6b662","type":"GlyphRenderer"},{"id":"0d5125c0-64fe-4035-8103-3de3e9dd356b","type":"GlyphRenderer"},{"id":"448de7fb-93fe-468e-a36a-75b8445aeaf7","type":"GlyphRenderer"},{"id":"c569e299-05f9-4f6f-a99a-5aaae5292736","type":"GlyphRenderer"},{"id":"56b66a75-fef0-4d65-a1cc-797ce67330bc","type":"GlyphRenderer"},{"id":"1f944c4b-4 ...

# %%
s = Scatter(data=test, x='rf', y='lr', height=300, width=700,
            tools='hover, box_zoom, save, reset',
            title='Comapring model predictions',
            xlabel='Random Forest',
            ylabel='Linear Regression',
            tooltips = [
              ('Make','@make'),
              ('MPG', '@mpg'),
              ('hp',  '@hp')
            ])

hover = s.select(dict(type=HoverTool))

hover.tooltips = [
    ('Make', '@make'),
    ('MPG', '@mpg'),
    ('hp', '@hp')
]

show(s)
# Out:
#   File "<ipython-input-31-038df5d0c81b>", line 14
#     hover.
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# Summary
# =======
# In this first lesson we explored a simple data analysis workflow and made use of three of the most popular packages in your Anaconda Open Data Science tool box:
#
# * Pandas for data import and processing
# * Bokeh for data visualization
# * Scikit-Learn for machine learning and predictive modeling

# %% [markdown]
# Go Further
# ==========
# 1. Run this notebook one cell at a time (by pressing CTRL-ENTER) and try experimenting with parameters. Interact with the visualizations.
#
# 2. Modify the scatter plot to examine different dimensions, such as *Year* vs. *Horsepower*, or *Displacement* vs. *Horsepower*.
#
# 3. Modify which features the `HoverTool` displays.
#
# 4. Try training the model with fewer features (e.g. try just *Displacement* and *Weight*) -- remember that when you exercise it to generate predictions you can only provide those features.
#
# 5. Try using the *K-Nearest Neighbor* or *Support Vector Classifier*.
